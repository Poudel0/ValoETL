# %%
import os
import pandas as pd
import json
import psycopg2

# %%
# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="valorant_test1":,
    user="postgres":,
    password="Password":,
    host="localhost":,
    port="5432"
)
cur = conn.cursor()

# %%
extra="Valorant_Champions_2024_-_Playoffs/double/80760/80760_extra.json"
details ="Valorant_Champions_2024_-_Playoffs/double/80760/180893_details.json"

# %%
with open(details, "r") as f:
    details = json.load(f)

with open(extra,'r') as f:
    extra = json.load(f)

# %%
Tournament ={
  "Tournament": {
    "eventID": "",
    "eventType": "",
    "eventFormat": "",
    "eventTier": "",
    "startDate": "",
    "eventName": "",
    "eventSlug": "",
    "childEvent": "",
    "childEventSlug": ""
  }
}

Matches={
  "Matches": {
    "matchID": "",
    "eventID": "",
    "eventStage": "",
    "bracket": "",
    "vlrID": "",
    "team1ID": "",
    "team2ID": "",
    "eventRegionID": "",
    "division": "",
    "t1Score": "",
    "t2Score": "",
    "bestOf": "",
    "patchID": ""
  }
}

Teams ={
  "Teams": {
    "teamID": "",
    "teamName": "",
    "teamShort": "",
    "region": ""
  }
}

Players={
  "Player": {
    "playerID": "",
    "ign": "",
    "oldIgn": "",
    "currentTeamID": ""
  }
}

mapsAvailable={
  "mapsAvailable": {
    "id": "",
    "name": "",
    "riotID": ""
  }
}

matchMapPickBans={
  "matchMapPickBans": {
    "matchID": "",
    "seqNum": "",
    "teamID": "",
    "mapID": "",
    "pickBanType": "",
    "isLeftover": "",
    "teamSeqNum": ""
  }
}

matchMaps={
  "matchMaps": {
    "mapID": "",
    "matchID": "",
    "mapNum": "",
    "lengthInMilli": "",
    "attackingFirst": "",
    "winner": "",
    "t1Score": "",
    "t2Score": "",
    "vodURL": ""
  }
}

matchMapStats={
  "matchMapStats": {
    "mapID": "",
    "playerID": "",
    "kills": "",
    "deaths": "",
    "assists": "",
    "ribRating": "",
    "ribRatingAttack": "",
    "ribRatingDefense": ""
  }
}

matchMapRounds={
  "matchMapRounds": {
    "roundID": "",
    "matchID": "",
    "roundNum": "",
    "winCondition": "",
    "winnerTeam": "",
    "ceremony": "",
    "t1LoadoutTier": "",
    "t2LoadoutTier": "",
    "attackingTeam": ""
  }
}

matchMapKills={
  "matchMapKills": {
    "id": "",
    "matchID": "",
    "roundID": "",
    "killerID": "",
    "victimID": "",
    "roundTimeMillis": "",
    "gameTimeMillis": "",
    "victimLocationX": "",
    "victimLocationY": "",
    "damageType": "",
    "abilityType": "",
    "weaponID": "",
    "secondaryFireMode": "",
    "isFirst": "",
    "tradedByKillID": "",
    "tradedForKillID": "",
    "weapon": "",
    "weaponCategory": "",
    "killerTeamNumber": "",
    "victimTeamNumber": "",
    "side": "",
    "assistants": ""
  }
}

matchMapXvYs={
  "matchMapXvYs": {
    "matchID": "",
    "teamID": "",
    "teamNumber": "",
    "side": "",
    "situation": "",
    "team1Count": "",
    "team2Count": "",
    "delta": "",
    "wins": "",
    "losses": ""
  }
}

matchMapPlayerStatsOnRounds={
  "matchMapPlayerStatsOnRounds": {
    "matchID": "",
    "roundID": "",
    "roundNumber": "",
    "playerID": "",
    "teamNumber": "",
    "side": "",
    "acs": "",
    "kills": "",
    "firstKills": "",
    "deaths": "",
    "firstDeaths": "",
    "assists": "",
    "damage": "",
    "headshots": "",
    "bodyshots": "",
    "legshots": "",
    "plants": "",
    "defusals": "",
    "clutches": "",
    "clutchOpponents": "",
    "clutchOpportunities": "",
    "impact": "",
    "kastRounds": ""
  }
}

matchMapPlayerStatsOnMaps={
  "matchMapPlayerStatsOnMaps": {
    "matchID": "",
    "playerID": "",
    "score": "",
    "roundsPlayed": "",
    "kills": "",
    "deaths": "",
    "assists": "",
    "playtimeMillis": "",
    "impact": "",
    "rating": "",
    "attackingRating": "",
    "defendingRating": ""
  }
}

matchMapEventsOnMaps= {
  "matchMapEventsOnMaps": {
    "roundID": "",
    "roundNumber": "",
    "roundTimeMillis": "",
    "killID": "",
    "tradedByKillID": "",
    "tradedForKillID": "",
    "bombID": "",
    "resID": "",
    "playerID": "",
    "assists": "",
    "referencePlayerID": "",
    "eventType": "",
    "damageType": "",
    "weaponID": "",
    "ability": "",
    "impact": "",
    "attackingWinProbabilityBefore": "",
    "attackingWinProbabilityAfter": "",
    "attackingTeamNumber": ""
  }
}

matchMapLocationsOnMaps ={
  "matchMapLocationsOnMaps": {
    "roundNumber": "",
    "playerID": "",
    "roundTimeMillis": "",
    "locationX": "",
    "locationY": "",
    "viewRadians": ""
  }
}

matchMapEconomiesOnMaps={
  "matchMapEconomiesOnMaps": {
    "roundID": "",
    "roundNumber": "",
    "playerID": "",
    "agentID": "",
    "score": "",
    "weaponID": "",
    "armorID": "",
    "remainingCreds": "",
    "spentCreds": "",
    "loadoutValue": "",
    "survived": "",
    "kast": ""
  }
}

Agents={
  "Agents": {
    "agentID": "",
    "name": "",
    "role": ""
  }
}

Abilities={
  "Abilities": {
    "abilityID": "",
    "agentID": "",
    "name": "",
    "slot": ""
  }
}

Weapons={
  "Weapons": {
    "weaponID": "",
    "name": "",
    "category": "",
    "cost": ""
  }
}

Armor={
  "Armor": {
    "armorID": "",
    "name": "",
    "cost": "",
    "damageReduction": ""
  }
}

Regions={
  "Regions": {
    "regionID": "",
    "name": ""
  }
}

Patches={
  "Patches": {
    "patchID": "",
    "releaseDate": "",
    "description": ""
  }
}

# %%
extra["id"]
# Out:
# 80760

# %%
Teams = {"Teams": []}

for team_key in ["team1", "team2"]:
    if team_key in extra:
        team_info = extra[team_key]
        team_entry = {
            "teamID": str(team_info.get("id", "")),
            "teamName": team_info.get("name", ""),
            "teamShort": team_info.get("shortName", ""),
            "region": team_info.get("vctRegion", "")
        }
        Teams["Teams"].append(team_entry)

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %%
def insert_tournament(self, event_data):
        """Insert tournament data"""
        query = """
        INSERT INTO Tournament (eventID, eventType, eventFormat, eventTier, startDate, 
                              eventName, eventSlug, childEvent, childEventSlug)
        VALUES (%(eventID)s, %(eventType)s, %(eventFormat)s, %(eventTier)s, %(startDate)s,
                %(eventName)s, %(eventSlug)s, %(childEvent)s, %(childEventSlug)s)
        ON CONFLICT (eventID) DO UPDATE SET
            eventName = EXCLUDED.eventName,
            startDate = EXCLUDED.startDate
        """
        
        # Map the event data to database fields
        tournament_data = {
            'eventID': event_data.get('parentEventId'),
            'eventType': event_data.get('eventType', 'VCT'),
            'eventFormat': event_data.get('eventFormat', 'LAN'),
            'eventTier': self._determine_event_tier(event_data.get('parentEventName', '')),
            'startDate': self._parse_date(event_data.get('startDate')),
            'eventName': event_data.get('parentEventName'),
            'eventSlug': event_data.get('parentEventSlug'),
            'childEvent': event_data.get('eventChildLabel'),
            'childEventSlug': event_data.get('eventSlug')
        }
        
        self.execute_query(query, tournament_data)
        logger.info(f"Inserted tournament: {tournament_data['eventName']}")

# %%
insert_tournament(extra)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 insert_tournament(extra)
#
# TypeError: insert_tournament() missing 1 required positional argument: 'event_data'
